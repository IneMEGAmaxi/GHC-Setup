# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.util import Node, Graph

# %%
graph = Graph()
graph.addNode("1")
graph.addNode("2")
graph.getNode("3").addIncoming(graph.getNode("2"), False)
graph.getNode("3").addIncoming("1", True)
graph.getNode("1").addOutgoing("2")

# %%
print(str(graph))
# Out:
# 1
# ->3 (True)
# ->2 (None)
#
# 2
# ->3 (False)
# <-1 (None)
#
# 3
# <-2 (False)
# <-1 (True)

# %%
graph.toDot()
